# %%
# convert received decimal bytes to ascii

# %%
ascii_list = [42,50,13,10,36,52,13,10,69,67,72,79,13,10,36,51,13,10,104,101,121,13,10]
bytes(ascii_list)
b'*2\r\n$4\r\nECHO\r\n$3\r\nhey\r\n'

# %%
# [72, 101, 121]
a=1
bytes([72, 101, 121]) # b'Hey'
# .decode("ascii")
# bytes([255, 0, 128, 13]).decode("ascii") #errro ascii[0-128]

bytes([255, 0, 128, 13])
# Out:
# b'\xff\x00\x80\r'

# %%
bytes([72, 101, 121]) # b'Hey'
# Out:
# b'Hey'

# %%
asdf =b'01000001'
import base64
diffbytes = base64.decodebytes(b'01000001')

# diffbytes.fromhex()
# repr(bytes.fromhex(hex_str).decode('ascii'))

# %%
ord("c")
# Out:
# 99

# %%
# "naïve"
byte_list = [0,0,0,0,0]
i=0
for c in "naïve":
    print(ord(c))
    byte_list[i]=ord(c)
    i+=1
    

# python:                        110 97 105     118 101
# bad [ASCII.GetBytes('naïve')]: 110 97 63      118 101
# good [UTF8.GetBytes('naïve')]: 110 97 195 175 118 101 na?ve
# Out:
# 110
# 97
# 239
# 118
# 101

# %%
# byte_list
# bin(255)      #'0b11111111'
# hex(255)      # 0xff

# bin(byte_list[0]) #'0b1101110'
# hex(byte_list[0])   #'0x6e'
for c in byte_list:
    print(chr(c))
# for b in byte_list:
# Out:
# n
# a
# ï
# v
# e

# %%
# 0xffff #65535
# 0x10000 #65536
0x10FFFF
# Out:
# 1114111
