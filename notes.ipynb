# %%
# convert received decimal bytes to ascii

# %%
ascii_list = [42,50,13,10,36,52,13,10,69,67,72,79,13,10,36,51,13,10,104,101,121,13,10]
bytes(ascii_list)
b'*2\r\n$4\r\nECHO\r\n$3\r\nhey\r\n'

# %%
# [72, 101, 121]
a=1
bytes([72, 101, 121]) # b'Hey'
# .decode("ascii")
# bytes([255, 0, 128, 13]).decode("ascii") #errro ascii[0-128]

bytes([255, 0, 128, 13])
# Out:
# b'\xff\x00\x80\r'

# %%
bytes([72, 101, 121]) # b'Hey'
# Out:
# b'Hey'

# %%
asdf =b'01000001'
import base64
base64.decodebytes(b'01000001')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 asdf =b'01000001'
#       2 import base64
# ----> 3 base64.encodestring('01000001')
#
# AttributeError: module 'base64' has no attribute 'encodestring'

# %%
# bin(255)      #'0b11111111'
# hex(255)      # 0xff
# Out:
# '0b11111111'
